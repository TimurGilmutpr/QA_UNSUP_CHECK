# %%
from RUN_ALL_LIB import *
import warnings
import gc
import torch
#warnings.filterwarnings("ignore", category=DeprecationWarning)
import os
os.environ["TRANSFORMERS_VERBOSITY"] = "error"
import logging
#logging.getLogger("transformers").setLevel(logging.ERROR)
import warnings
#warnings.filterwarnings("ignore", message="Setting `pad_token_id` to `eos_token_id`")

# %%
# ==================== QA LoRA 4BIT TEST 1 — базовый вариант ====================

run_lora(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    quantization_config="4bit",
    max_new_tokens=1300,
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=1e-5,
    test_status=False,
    test_trained = None,
    optim="paged_adamw_8bit",
    lora_r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
)

# %% [raw]
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# Loading weights: 100%
#  291/291 [00:01<00:00, 281.45it/s]
# Adding EOS to train dataset: 100%
#  940/940 [00:00<00:00, 40578.90 examples/s]
# Tokenizing train dataset: 100%
#  940/940 [00:00<00:00, 1291.83 examples/s]
# Truncating train dataset: 100%
#  940/940 [00:00<00:00, 133775.98 examples/s]
# Adding EOS to eval dataset: 100%
#  105/105 [00:00<00:00, 25082.69 examples/s]
# Tokenizing eval dataset: 100%
#  105/105 [00:00<00:00, 1493.69 examples/s]
# Truncating eval dataset: 100%
#  105/105 [00:00<00:00, 33348.62 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#  [354/354 17:08, Epoch 3/3]
# Epoch	Training Loss	Validation Loss
# 1	1.468373	1.409600
# 2	1.131988	1.146962
# 3	1.101107	1.135528
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%
#  291/291 [00:01<00:00, 278.32it/s]

# %%
# ==================== QA LoRA 4BIT TEST 2 — меньше LR, стабильнее ====================

run_lora(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    quantization_config="4bit",
    max_new_tokens=1300,
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=5e-6,
    test_status=False,
    optim="paged_adamw_8bit",
    lora_r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    test_trained = None,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
)

# %% [raw]
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# Loading weights: 100%
#  291/291 [00:01<00:00, 287.93it/s]
# Adding EOS to train dataset: 100%
#  940/940 [00:00<00:00, 42340.32 examples/s]
# Tokenizing train dataset: 100%
#  940/940 [00:00<00:00, 1437.02 examples/s]
# Truncating train dataset: 100%
#  940/940 [00:00<00:00, 156336.32 examples/s]
# Adding EOS to eval dataset: 100%
#  105/105 [00:00<00:00, 24510.35 examples/s]
# Tokenizing eval dataset: 100%
#  105/105 [00:00<00:00, 1530.75 examples/s]
# Truncating eval dataset: 100%
#  105/105 [00:00<00:00, 36312.82 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#  [354/354 17:08, Epoch 3/3]
# Epoch	Training Loss	Validation Loss
# 1	1.747438	1.710393
# 2	1.561911	1.568075
# 3	1.538158	1.562086

# %%
# ==================== QA LoRA 4BIT TEST 3 — больше эпох ====================

run_lora(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    quantization_config="4bit",
    max_new_tokens=1300,
    num_epoch=5,
    batch_size=1,
    grad_accum_steps=8,
    lr=5e-6,
    test_status=False,
    test_trained = None,
    optim="paged_adamw_8bit",
    lora_r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
)

# %% [raw]
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# Loading weights: 100%
#  291/291 [00:01<00:00, 283.22it/s]
# Adding EOS to train dataset: 100%
#  940/940 [00:00<00:00, 40784.58 examples/s]
# Tokenizing train dataset: 100%
#  940/940 [00:00<00:00, 1420.71 examples/s]
# Truncating train dataset: 100%
#  940/940 [00:00<00:00, 161550.74 examples/s]
# Adding EOS to eval dataset: 100%
#  105/105 [00:00<00:00, 25188.85 examples/s]
# Tokenizing eval dataset: 100%
#  105/105 [00:00<00:00, 1479.95 examples/s]
# Truncating eval dataset: 100%
#  105/105 [00:00<00:00, 26552.63 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#  [590/590 28:39, Epoch 5/5]
# Epoch	Training Loss	Validation Loss
# 1	1.731788	1.689000
# 2	1.468397	1.463964
# 3	1.349025	1.370556
# 4	1.337879	1.354007
# 5	1.315057	1.354019

# %%
# ==================== QA LoRA 4BIT TEST 4 — больше LoRA rank ====================

run_lora(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    quantization_config="4bit",
    max_new_tokens=1300,
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=1e-5,
    test_status=False,
    test_trained = None,
    optim="paged_adamw_8bit",
    lora_r=32,
    lora_alpha=64,
    lora_dropout=0.05,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
)

# %% [raw]
# ===== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# Loading weights: 100%
#  291/291 [00:01<00:00, 288.47it/s]
# Adding EOS to train dataset: 100%
#  940/940 [00:00<00:00, 41829.12 examples/s]
# Tokenizing train dataset: 100%
#  940/940 [00:00<00:00, 1424.86 examples/s]
# Truncating train dataset: 100%
#  940/940 [00:00<00:00, 147852.91 examples/s]
# Adding EOS to eval dataset: 100%
#  105/105 [00:00<00:00, 23279.52 examples/s]
# Tokenizing eval dataset: 100%
#  105/105 [00:00<00:00, 1504.75 examples/s]
# Truncating eval dataset: 100%
#  105/105 [00:00<00:00, 36918.60 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#  [354/354 17:10, Epoch 3/3]
# Epoch	Training Loss	Validation Loss
# 1	1.180529	1.125375
# 2	0.796529	0.827675
# 3	0.730727	0.803578

# %%
# ==================== QA LoRA 4BIT TEST 5 — больше модулей LoRA ====================

run_lora(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    quantization_config="4bit",
    max_new_tokens=1300,
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=1e-5,
    test_status=False,
    test_trained = None,
    optim="paged_adamw_8bit",
    lora_r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
)

# %% [raw]
# ==== LORA: meta-llama/Llama-3.1-8B-Instruct =====
# Loading weights: 100%
#  291/291 [00:01<00:00, 293.13it/s]
# Adding EOS to train dataset: 100%
#  940/940 [00:00<00:00, 40185.97 examples/s]
# Tokenizing train dataset: 100%
#  940/940 [00:00<00:00, 1584.22 examples/s]
# Truncating train dataset: 100%
#  940/940 [00:00<00:00, 149529.55 examples/s]
# Adding EOS to eval dataset: 100%
#  105/105 [00:00<00:00, 18620.07 examples/s]
# Tokenizing eval dataset: 100%
#  105/105 [00:00<00:00, 1451.49 examples/s]
# Truncating eval dataset: 100%
#  105/105 [00:00<00:00, 33409.34 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#  [354/354 19:55, Epoch 3/3]
# Epoch	Training Loss	Validation Loss
# 1	0.929661	0.875250
# 2	0.489629	0.527111
# 3	0.442155	0.504425
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100%
#  291/291 [00:01<00:00, 295.18it/s]
