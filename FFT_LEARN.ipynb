# %%
from RUN_ALL_LIB import *
import warnings
import gc
import torch
#warnings.filterwarnings("ignore", category=DeprecationWarning)
import os
os.environ["TRANSFORMERS_VERBOSITY"] = "error"
import logging
#logging.getLogger("transformers").setLevel(logging.ERROR)
import warnings
#warnings.filterwarnings("ignore", message="Setting `pad_token_id` to `eos_token_id`")

# %%
# ==================== FFT QA TEST 1 ====================

run_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    max_new_tokens=1300,
    num_epoch=3,
    test_status=False,
    learn_len=512,
    batch_size=1,
    device_batch_size=1,
    padding=False,
    data_collator_type="new",
)

# %% [raw]
# ===== FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading widget...
# Loading widget...
# Loading widget...
#  [177/177 06:17, Epoch 3/3]
# Epoch	Training Loss	Validation Loss
# 1	0.261471	0.217478
# 2	0.134586	0.132731
# 3	0.106895	0.126220
# Loading widget...
# Loading widget...
# Loading widget...

# %%
# ==================== FFT QA TEST 2 ====================

run_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    max_new_tokens=1300,
    num_epoch=3,
    test_status=False,
    learn_len=512,
    batch_size=1,
    device_batch_size=1,
    padding=False,
    data_collator_type="old",
    make_test = False
)
# Out:
# ===== FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='177' max='177' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [177/177 06:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.311083</td>
#       <td>0.263769</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.184638</td>
#       <td>0.179833</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.151295</td>
#       <td>0.166263</td>
#     </tr>
#   </tbody>
# </table><p>
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# ==================== FFT QA TEST 3 ====================

run_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    max_new_tokens=1300,
    num_epoch=5,
    test_status=False,
    learn_len=512,
    batch_size=1,
    device_batch_size=1,
    padding=False,
    data_collator_type="new",
    make_test = False
)
# Out:
# ===== FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='295' max='295' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [295/295 10:10, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.244820</td>
#       <td>0.198956</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.109155</td>
#       <td>0.102958</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.071417</td>
#       <td>0.086905</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.053543</td>
#       <td>0.082386</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.046631</td>
# ...

# %%
# ==================== FFT QA TEST 4 ====================

run_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    max_new_tokens=1300,
    num_epoch=3,
    test_status=False,
    learn_len=1024,
    batch_size=1,
    device_batch_size=1,
    padding=False,
    data_collator_type="new",
    make_test = False
)
# Out:
# ===== FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='177' max='177' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [177/177 07:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.290294</td>
#       <td>0.251540</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.144068</td>
#       <td>0.152927</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.103389</td>
#       <td>0.144262</td>
#     </tr>
#   </tbody>
# </table><p>
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# ==================== FFT QA TEST 5 ====================

run_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    token=os.getenv("HF_TOKEN"),
    max_new_tokens=1300,
    num_epoch=5,
    test_status=False,
    learn_len=1024,
    batch_size=1,
    device_batch_size=1,
    padding=False,
    data_collator_type="new",
    make_test = False
)
# Out:
# ===== FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/105 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='295' max='295' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [295/295 13:13, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.274164</td>
#       <td>0.231630</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.118509</td>
#       <td>0.116011</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.065689</td>
#       <td>0.095409</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.047853</td>
#       <td>0.090352</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.052937</td>
# ...

# %%
# ==================== FFT UNSUP TEST 1 ====================

run_unsupervised_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    corpus_path="dataset.txt",
    token=os.getenv("HF_TOKEN"),
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=1e-5,
    max_seq_length=512,
    chunk_size_sym=1500,
    overlap_sym=150,
    val_split=0.05,
    optim="adamw_torch_fused",
    test_status=False,
    make_test = False,
)
# Out:
# ===== UNSUPERVISED FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct on dataset.txt =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/72 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='510' max='510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [510/510 09:25, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.103413</td>
#       <td>2.119750</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.956176</td>
#       <td>2.078020</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.953598</td>
#       <td>2.073710</td>
#     </tr>
#   </tbody>
# ...

# %%
# ==================== FFT UNSUP TEST 2 ====================

run_unsupervised_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    corpus_path="dataset.txt",
    token=os.getenv("HF_TOKEN"),
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=8,
    lr=5e-6,
    max_seq_length=512,
    chunk_size_sym=1500,
    overlap_sym=150,
    val_split=0.05,
    optim="adamw_torch_fused",
    test_status=False,
    make_test = False
)
# Out:
# ===== UNSUPERVISED FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct on dataset.txt =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/72 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='510' max='510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [510/510 09:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.257616</td>
#       <td>2.277273</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.167498</td>
#       <td>2.245684</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.195190</td>
#       <td>2.241374</td>
#     </tr>
#   </tbody>
# ...

# %%
# ==================== FFT UNSUP TEST 3 ====================

run_unsupervised_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    corpus_path="dataset.txt",
    token=os.getenv("HF_TOKEN"),
    num_epoch=5,
    batch_size=1,
    grad_accum_steps=8,
    lr=5e-6,
    max_seq_length=512,
    chunk_size_sym=1500,
    overlap_sym=150,
    val_split=0.05,
    optim="adamw_torch_fused",
    test_status=False,
)
# Out:
# ===== UNSUPERVISED FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct on dataset.txt =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/72 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='850' max='850' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [850/850 15:52, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.246269</td>
#       <td>2.264689</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.137473</td>
#       <td>2.214204</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.141588</td>
#       <td>2.196288</td>
#     </tr>
#     <tr>
# ...

# %%
# ==================== FFT UNSUP TEST 4 ====================

run_unsupervised_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    corpus_path="dataset.txt",
    token=os.getenv("HF_TOKEN"),
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=12,
    lr=1e-5,
    max_seq_length=1024,
    chunk_size_sym=3000,
    overlap_sym=300,
    val_split=0.05,
    optim="adamw_torch_fused",
    test_status=False,
)
# Out:
# ===== UNSUPERVISED FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct on dataset.txt =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/36 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='171' max='171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [171/171 07:33, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.075125</td>
#       <td>2.094832</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.010468</td>
#       <td>2.059909</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.952153</td>
#       <td>2.056091</td>
#     </tr>
#   </tbody>
# ...

# %%
# ==================== FFT UNSUP TEST 5 ====================

run_unsupervised_full_finetune(
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    corpus_path="dataset.txt",
    token=os.getenv("HF_TOKEN"),
    num_epoch=3,
    batch_size=1,
    grad_accum_steps=12,
    lr=5e-6,
    max_seq_length=1024,
    chunk_size_sym=3000,
    overlap_sym=300,
    val_split=0.05,
    optim="adamw_torch_fused",
    test_status=False,
)
# Out:
# ===== UNSUPERVISED FULL FINETUNE: meta-llama/Llama-3.1-8B-Instruct on dataset.txt =====
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Map:   0%|          | 0/36 [00:00<?, ? examples/s]
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
#     <div>
#
#       <progress value='171' max='171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [171/171 07:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.192868</td>
#       <td>2.218669</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.179235</td>
#       <td>2.193723</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.138176</td>
#       <td>2.190775</td>
#     </tr>
#   </tbody>
# ...
